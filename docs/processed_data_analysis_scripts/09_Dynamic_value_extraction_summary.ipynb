# %%
'''
[00] cell volume 
[01] Final chromosome-to-chromosome distance
[02] Final pole-to-pole distance
[03] Final pole-to-chromosome distance 
[04] metaphase pole-to-pole distance
[05] elongation rate pole-to-pole distance
[06] segregation rate for chromosome-to-chromosome distance
'''
# Out:
# '\n[00] cell volume \n[01] Final chromosome-to-chromosome distance\n[02] Final pole-to-pole distance\n[03] Final pole-to-chromosome distance \n[04] metaphase pole-to-pole distance\n[05] elongation rate pole-to-pole distance\n[06] segregation rate for chromosome-to-chromosome distance\n'

# %%
# library packages
import os
import pandas as pd
import numpy as np
from DynamicsSummary import cellDynamicsValues
from DynamicsAnalysisSummary import spindleDynamicsValues

# %%
# input folder
folder = r'D:\data\Analysis Data\python_analysis\input'
fileTable = os.listdir(folder)

# # output folder
save_files = r'D:\data\Analysis Data\python_analysis\output'

# %%
# call function to compute for different parameters (see library script)

# %%
spindleDynamicsValues(0,1,2,3,4,5,6,7, folder, fileTable, save_files, 'Dynamics_analysis_summary', 'big')
