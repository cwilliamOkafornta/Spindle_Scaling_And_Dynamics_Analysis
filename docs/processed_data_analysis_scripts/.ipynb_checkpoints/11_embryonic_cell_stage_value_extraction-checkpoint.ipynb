# %%
# library packages
import os 
import pandas as pd
import numpy as np
from cellStageExtract_wt import extract2cellstage_wt, extract4cellstage_wt, extract8cellstage_wt, extract16cellstage_wt, extract32cellstage_wt, extract64cellstage_wt
from cellStageExtract_small import extract2cellstage_small, extract4cellstage_small, extract8cellstage_small, extract16cellstage_small, extract32cellstage_small, extract64cellstage_small
from cellStageExtract_big import extract2cellstage_big, extract4cellstage_big, extract8cellstage_big, extract16cellstage_big, extract32cellstage_big, extract64cellstage_big

# %%
# define the folder path
# input
file_path = 'D:/data/Analysis Data/python_analysis/input'
data_files = os.listdir(file_path)

# output
folder_save = 'D:/data/Analysis Data/python_analysis/output'

# %%
'''Parameter for WT embryo data files'''
# pole_to_pole
# Exp_names = ['Exp17pp', 'Exp19pp', 'Exp20pp', 'Exp28pp', 'Exp29pp', 'Exp30pp', 'Exp32pp', 'Exp33pp', 'Exp37pp', 'Exp42pp', 'Exp45pp']

# chromosome_to_chromosome
# Exp_names = ['Exp17cc', 'Exp19cc', 'Exp20cc', 'Exp28cc', 'Exp29cc', 'Exp30cc', 'Exp32cc', 'Exp33cc', 'Exp37cc', 'Exp42cc', 'Exp45cc']
# Out:
# 'Parameter for WT embryo data files'

# %%
'''Parameter for small embryo data files'''
# pole_to_pole
# Exp_names = ['Exp49a_pp', 'Exp49b_pp', 'Exp50a_pp', 'Exp50b_pp', 'Exp51a_pp', 'Exp51b_pp', 'Exp74_pp', 'Exp75_pp']

# chromosome_to_chromosome
# Exp_names = ['Exp49a_cc', 'Exp49b_cc', 'Exp50a_cc', 'Exp50b_cc', 'Exp51a_cc', 'Exp51b_cc', 'Exp74_cc', 'Exp75_cc']
# Out:
# 'Parameter for small embryo data files'

# %%
'''Parameter for small embryo data files'''
# pole_to_pole
Exp_names = ['Exp55a_pp', 'Exp55b_pp', 'Exp58_pp', 'Exp59a_pp', 'Exp62a_pp', 'Exp65a_pp', 'Exp66b_pp', 'Exp69_pp', 'Exp70b_pp']

# chromosome_to_chromosome
# Exp_names = ['Exp55a_cc', 'Exp55b_cc', 'Exp58_cc', 'Exp59a_cc', 'Exp62a_cc', 'Exp65a_cc', 'Exp66b_cc', 'Exp69_cc', 'Exp70b_cc']

# %%
# # Wild type
# extract2cellstage_wt(file_path, folder_save, data_files, Exp_names)
# extract4cellstage_wt(file_path, folder_save, data_files, Exp_names)
# extract8cellstage_wt(file_path, folder_save, data_files, Exp_names)
# extract16cellstage_wt(file_path, folder_save, data_files, Exp_names)
# extract32cellstage_wt(file_path, folder_save, data_files, Exp_names)
# extract64cellstage_wt(file_path, folder_save, data_files, Exp_names)

# %%
# # small 
# extract2cellstage_small(file_path, folder_save, data_files, Exp_names)
# extract4cellstage_small(file_path, folder_save, data_files, Exp_names)
# extract8cellstage_small(file_path, folder_save, data_files, Exp_names)
# extract16cellstage_small(file_path, folder_save, data_files, Exp_names)
# extract32cellstage_small(file_path, folder_save, data_files, Exp_names)
# extract64cellstage_small(file_path, folder_save, data_files, Exp_names)

# %%
# big 
extract2cellstage_big(file_path, folder_save, data_files, Exp_names)
extract4cellstage_big(file_path, folder_save, data_files, Exp_names)
extract8cellstage_big(file_path, folder_save, data_files, Exp_names)
extract16cellstage_big(file_path, folder_save, data_files, Exp_names)
extract32cellstage_big(file_path, folder_save, data_files, Exp_names)
extract64cellstage_big(file_path, folder_save, data_files, Exp_names)
