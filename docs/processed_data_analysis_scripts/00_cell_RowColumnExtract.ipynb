# %% [markdown]
# ### <h1 align="center">**Poles 3D-coordinates value extraction**</h1>
#
# This script is used to call the **SpotCoordinateExtract** library to extract the X, Y, Z coordinates of **pole 1** and **pole 2**. The input csv file is generated from Fiji ROI Manager after correcting the spots that were missed by the **Spot detection script**.

# %%
# library package
import pandas as pd
import numpy as np
import os
from RowColumnExtract import SpotCoordinateExtract

# %%
# input folder
folder = r"D:/data/Analysis Data/Exp_data/Exp_RNAi_c27d9.1/Exp65a_tmr31-c27d9-1-04cell_LLSM_20220214/Exp65a_tmr31-c27d9-1-04cell_LLSM_20220214_Analysis/64cell_ABalpaa/64cell_ABalpaa_ImageJ"

# output folder
save_folder = r"D:/data/Analysis Data/Exp_data/Exp_RNAi_c27d9.1/Exp65a_tmr31-c27d9-1-04cell_LLSM_20220214/Exp65a_tmr31-c27d9-1-04cell_LLSM_20220214_Analysis/64cell_ABalpaa/64cell_ABalpaa_ImageJ"

# %%
# call the function
SpotCoordinateExtract(folder, save_folder, 'Overlay Elements of 64cell_ABalpaa.csv', '64cell_ABalpaa_coordinates.csv')
