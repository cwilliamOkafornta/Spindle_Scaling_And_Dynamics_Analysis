# %% [markdown]
# ### <h1 align="center">**Poles 3D-coordinates value extraction**</h1>
#
# This script is used to call the **SpotCoordinateExtract** library to extract the X, Y, Z coordinates of **pole 1** and **pole 2**. The input csv file is generated from Fiji ROI Manager after correcting the spots that were missed by the **Spot detection script**.

# %%
# library package
from RowColumnExtract import SpotCoordinateExtract

# %%
# input folder
folder = r"D:\data\Analysis Data\Exp_data\Exp_RNAi_c27d9.1\Exp69_tmr31-c27d9-1-02cell_LLSM_20220223\Exp69_tmr31-c27d9-1-02cell_LLSM_20220223_Analysis\2cell_P1\2cell_P1_ImageJ"

# output folder
save_folder = r"D:\data\Analysis Data\Exp_data\Exp_RNAi_c27d9.1\Exp69_tmr31-c27d9-1-02cell_LLSM_20220223\Exp69_tmr31-c27d9-1-02cell_LLSM_20220223_Analysis\2cell_P1\2cell_P1_ImageJ"

# %%
# call the function
SpotCoordinateExtract(folder, save_folder, 'Overlay Elements of 2cell_P1.csv', '2cell_P1_coordinates.csv')
