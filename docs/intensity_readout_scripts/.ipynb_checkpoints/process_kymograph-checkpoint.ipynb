# %%
# library packages 
import os
import glob
import matplotlib
import numpy as np
import pandas as pd
from skimage import io
from pathlib import Path
from scipy.signal import find_peaks
from matplotlib import pyplot as plt
from scipy.signal import argrelextrema
from skimage.io import imread, imshow, imsave
from skimage.transform import rescale, resize,downscale_local_mean
from embryo_analyses_library import KyMeas, find_maxima, filterMaxima, findChromosomeMaxima, plotMaxima, reformatPositionsPoles, reformatPositionsChromosome
from embryo_analyses_library import plotDistances, savecsvfile, kymoDistance, guessThreshold, ChromosomeMaximaQuality

# %%
path = "D:/data/Analysis Data/kymo_analysis/E32"
output_csv = "D:/data/Analysis Data/kymo_analysis/E32/output_csv"
output_plot = "D:/data/Analysis Data/kymo_analysis/E32/output_plots"

output_csv_chromosome = "D:/data/Analysis Data/kymo_analysis/E32/output_csv_chromosome"
output_plot_chromosome = "D:/data/Analysis Data/kymo_analysis/E32/output_plot_chromosome"

output_rescaled_kymo = "D:/data/Analysis Data/kymo_analysis/E32/output_rescaled_kymo"

# %%
image_file_list = KyMeas(path,'tif')

# %%
# call and execute the analyses functions from the library        
def analyzeFile(filename, folder):
    """
    rescale the kymograph for visualization, save and apply the other function on each file while saving the outputs
    in different  sub-folders
    """
    # read the image file, crop out the unwanted frame (optional), rescale the image and save
    input_image = imread(filename)
    input_image_cropped = input_image[:, 3:25, :]
    print(input_image.shape)
    input_image_rescale = rescale(input_image, [1, 10, 1], anti_aliasing = False) 
    input_img_rescale_join = os.path.join(folder, filename.split("/")[-1]).replace("\\", "/")
    imsave(input_img_rescale_join, input_image_rescale[1])
    
    # calculate the average threshold using the guessThreshold function and introduce error message when it fails
    try: 
        threshold = guessThreshold(input_image)
        filename = filename.split("/")[-1]
        print("Image", filename, "can be nicely processed with threshold:", threshold)

    # continue analyzing other files if one file cannot be analyse.
    except ZeroDivisionError:
        print("Image", filename, "cannot be analysed")
        return 
    
    # apply the functions for different operations for both the centrosome and chromosome detection
    
    """FOR CENTROSOME (POLES)"""
    maxima_x = find_maxima(input_image, threshold, channel = 1) 
    #plotMaxima(maxima_x) # show the maxima for each timepoint before filtering
    maxima = filterMaxima(maxima_x, 50)
    print(filename, ": filtered")
   
    centromosomes_table = reformatPositionsPoles(maxima) # read out the position of the maxima for centrosome
    print("Pole maxima positions\n", centromosomes_table)
    
    plotMaxima(maxima) # plotting the centrosome after filtering out the unwanted maxima
    
    """FOR CHROMOSOME"""
    #find the maxima for the chromosome channel and output the intensity in plot
    maxima_chromosome = find_maxima(input_image_cropped, threshold, channel = 0)
    #plotMaxima(maxima_chromosome)
    
    MaxFindChromosome = findChromosomeMaxima(maxima, maxima_chromosome)
    #plotMaxima(MaxFindChromosome)
    filterChromosomeMaxima = filterMaxima(MaxFindChromosome, 50)
    
    chromosome_table = reformatPositionsChromosome(filterChromosomeMaxima) # read out the position of the maxima for chromosome
    print("Chromosome maxima positions\n", chromosome_table)

    plotMaxima(filterChromosomeMaxima)  
    #print(filterChromosomeMaxima)
        
    # calculate and display the quality of the chromosome maxima detected on a scale of 0 and 1 (1 been the best)
    quality = ChromosomeMaximaQuality(filterChromosomeMaxima)
    print("Quality: ", quality)
    
    
    """FOR CENTROSOME (POLES)"""
    
    print("Centromsome distance")
    
    # calculate the distance between the detected maximum
    frames, distances = kymoDistance(maxima) 
    
    #plot the distance and save in a given format
    plotfilename = filename.split("/")[-1] 
    plotfilename = plotfilename.split(".")[0] + ".png"  
    plotDistances(plotfilename, output_plot, frames, distances) # 
    
    # save the distance values in csv files
    csvfilename = filename + ".csv"
    savecsvfile(csvfilename, output_csv, frames, distances)
    
    
    """FOR CHROMOSOME"""
    
    print("Chromosome distance")
    
    # calculate the distance between the detected maximum
    frames_chromosome, distances_chromosome = kymoDistance(filterChromosomeMaxima)
    
    #plot the distance and save in a given format
    plotDistances(plotfilename, output_plot_chromosome, frames_chromosome, distances_chromosome)
    
    # save the distance values in csv files
    csvfilename = filename + ".csv"
    savecsvfile(csvfilename, output_csv_chromosome, frames_chromosome, distances_chromosome)
    
    return quality
    
# initialize the count of the data analyzed using low and high quality variables
count_high_quality_dataset = 0
count_low_quality_dataset = 0
count_errors = 0

# read through the file in the defined folder and apply the analysis functions
for file in image_file_list:
    try:
        quality_analyses = analyzeFile(file, output_rescaled_kymo)
        if quality_analyses >= 0.9:
            count_high_quality_dataset = count_high_quality_dataset+1
        else:
            count_low_quality_dataset = count_low_quality_dataset+1
    except:
        print('Error: maxima were incorrectly detected', file)
        
        count_errors = count_errors+1
        
    #break
        
print("High quality detection: ", count_high_quality_dataset)
print("Low quality detection: ", count_low_quality_dataset)
print("Number of errors: ", count_errors)
# Out:
# (2, 31, 650)
# Average_threshold: 4995.0
# Image 2cell_AB_kymo.tif can be nicely processed with threshold: 4995.0
# 2cell_AB_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      276     379
# 1      278     376
# 2      276     374
# 3      277     375
# 4      274     379
# 5      275     379
# 6      270     380
# 7      265     382
# 8      266     383
# 9      263     386
# 10     261     391
# 11     258     396
# 12     254     398
# 13     249     400
# 14     248     405
# 15     248     406
# 16     242     409
# 17     238     406
# 18     232     411
# 19     232     412
# 20     229     416
# 21     232     417
# 22     228     414
# 23     233     417
# 24     231     416
# 25     230     414
# 26     226     420
# 27     229     421
# 28     228     417
# 29     227     420
# 30     228     423
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            333           333
# 1            330           330
# 2            333           333
# 3            331           331
# 4            330           330
# 5            331           331
# 6            329           329
# 7            331           331
# 8            325           341
# 9            318           345
# 10           311           347
# 11           311           353
# 12           310           354
# 13           306           356
# 14           305           356
# 15           298           354
# 16           298           356
# 17           293           355
# 18           298           360
# 19           295           362
# 20           364           382
# 21           381           384
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 650)
# Average_threshold: 4995.0
# Image 2cell_P1_kymo.tif can be nicely processed with threshold: 4995.0
# 2cell_P1_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      284     366
# 1      279     365
# 2      279     370
# 3      273     373
# 4      274     370
# 5      272     370
# 6      271     376
# 7      267     379
# 8      262     385
# 9      260     389
# 10     254     392
# 11     250     396
# 12     253     397
# 13     252     397
# 14     248     399
# 15     249     408
# 16     245     404
# 17     244     405
# 18     240     405
# 19     239     409
# 20     235     407
# 21     234     408
# 22     236     413
# 23     235     409
# 24     234     414
# 25     235     418
# 26     232     417
# 27     231     413
# 28     233     413
# 29     233     413
# 30     235     414
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            321           321
# 1            320           320
# 2            319           319
# 3            321           321
# 4            323           323
# 5            321           321
# 6            319           319
# 7            311           331
# 8            305           337
# 9            332           340
# 10           301           346
# 11           299           344
# 12           302           351
# 13           298           351
# 14           296           353
# 15           290           349
# 16           340           351
# 17           351           351
# 18           355           355
# 19           355           355
# 20           356           356
# 21           358           358
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 610)
# Average_threshold: 4995.0
# Image 4cell_ABa_kymo.tif can be nicely processed with threshold: 4995.0
# 4cell_ABa_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      251     358
# 1      254     357
# 2      258     356
# 3      262     351
# 4      263     354
# 5      262     353
# 6      260     355
# 7      257     357
# 8      255     358
# 9      252     363
# 10     251     366
# 11     246     367
# 12     239     374
# 13     236     379
# 14     230     378
# 15     232     383
# 16     227     386
# 17     225     387
# 18     224     391
# 19     222     392
# 20     220     393
# 21     221     393
# 22     218     393
# 23     218     395
# 24     220     394
# 25     220     395
# 26     221     396
# 27     221     396
# 28     220     391
# 29     219     396
# 30     221     394
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            307           307
# 1            311           311
# 2            311           311
# 3            311           311
# 4            308           308
# 5            308           308
# 6            307           307
# 7            309           309
# 8            314           314
# 9            321           346
# 10           287           327
# 11           279           329
# 12           282           334
# 13           278           335
# 14           274           335
# 15           275           338
# 16           273           337
# 17           272           336
# 18           272           336
# 19           269           336
# 20           269           338
# 21           270           338
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 620)
# Average_threshold: 4995.0
# Image 4cell_ABp_kymo.tif can be nicely processed with threshold: 4995.0
# 4cell_ABp_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      254     362
# 1      257     356
# 2      260     357
# 3      257     356
# 4      256     358
# 5      253     359
# 6      255     363
# 7      253     362
# 8      250     363
# 9      248     367
# 10     244     374
# 11     234     377
# 12     234     380
# 13     232     385
# 14     227     388
# 15     226     390
# 16     222     391
# 17     221     396
# 18     218     394
# 19     220     398
# 20     215     396
# 21     217     396
# 22     216     398
# 23     214     399
# 24     213     401
# 25     211     400
# 26     213     402
# 27     213     402
# 28     212     401
# 29     211     401
# 30     213     402
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            305           305
# 1            305           305
# 2            302           302
# 3            305           305
# 4            306           306
# 5            303           303
# 6            304           304
# 7            301           301
# 8            289           319
# 9            284           325
# 10           280           329
# 11           276           331
# 12           276           335
# 13           273           336
# 14           272           337
# 15           270           337
# 16           272           339
# 17           267           338
# 18           268           338
# 19           268           338
# 20           268           336
# 21           266           339
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 590)
# Average_threshold: 4995.0
# Image 4cell_EMS_kymo.tif can be nicely processed with threshold: 4995.0
# 4cell_EMS_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      247     338
# 1      254     338
# 2      255     334
# 3      256     334
# 4      257     337
# 5      255     336
# 6      254     335
# 7      255     335
# 8      251     337
# 9      246     345
# 10     245     346
# 11     237     355
# 12     232     360
# 13     232     364
# 14     225     361
# 15     227     363
# 16     223     368
# 17     219     369
# 18     219     368
# 19     219     371
# 20     218     370
# 21     218     372
# 22     214     374
# 23     211     375
# 24     214     375
# 25     214     376
# 26     211     381
# 27     209     381
# 28     206     383
# 29     207     383
# 30     207     384
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            293           293
# 1            292           292
# 2            294           294
# 3            294           294
# 4            293           293
# 5            294           294
# 6            296           296
# 7            298           298
# 8            306           306
# 9            281           311
# 10           280           316
# 11           270           310
# 12           268           316
# 13           269           318
# 14           266           318
# 15           265           318
# 16           262           319
# 17           264           321
# 18           264           325
# 19           258           319
# 20           258           320
# 21           262           316
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 560)
# Average_threshold: 4995.0
# Image 4cell_P2_kymo.tif can be nicely processed with threshold: 4995.0
# 4cell_P2_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      232     329
# 1      235     327
# 2      235     324
# 3      239     320
# 4      243     320
# 5      241     319
# 6      240     319
# 7      238     317
# 8      237     321
# 9      234     322
# 10     231     323
# 11     228     329
# 12     223     334
# 13     219     336
# 14     217     341
# 15     214     342
# 16     211     341
# 17     210     345
# 18     208     349
# 19     209     351
# 20     208     354
# 21     205     354
# 22     206     354
# 23     204     355
# 24     205     358
# 25     204     355
# 26     203     357
# 27     203     357
# 28     200     357
# 29     203     359
# 30     204     359
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            285           285
# 1            283           283
# 2            283           283
# 3            283           283
# 4            281           281
# 5            281           281
# 6            282           282
# 7            281           281
# 8            277           277
# 9            270           294
# 10           263           297
# 11           261           305
# 12           258           306
# 13           255           305
# 14           255           307
# 15           254           307
# 16           252           308
# 17           254           311
# 18           253           311
# 19           250           312
# 20           252           314
# 21           252           302
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 580)
# Average_threshold: 4995.0
# Image 8cell_ABal_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_ABal_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      247     333
# 1      250     330
# 2      249     332
# 3      250     327
# 4      251     330
# 5      254     327
# 6      252     327
# 7      253     327
# 8      251     328
# 9      249     330
# 10     246     334
# 11     237     342
# 12     235     345
# 13     233     348
# 14     231     348
# 15     230     350
# 16     229     351
# 17     226     352
# 18     224     353
# 19     226     355
# 20     227     355
# 21     224     355
# 22     224     355
# 23     223     356
# 24     223     356
# 25     220     357
# 26     222     359
# 27     219     360
# 28     218     361
# 29     214     361
# 30     216     361
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            288           288
# 1            289           289
# 2            287           287
# 3            287           287
# 4            288           288
# 5            288           288
# 6            288           288
# 7            290           290
# 8            276           298
# 9            272           303
# 10           269           309
# 11           267           311
# 12           266           311
# 13           264           313
# 14           261           313
# 15           260           314
# 16           261           317
# 17           262           319
# 18           260           320
# 19           264           321
# 20           260           314
# 21           259           320
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 430)
# Average_threshold: 4995.0
# Image 8cell_ABar_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_ABar_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      167     262
# 1      166     259
# 2      169     257
# 3      173     254
# 4      171     251
# 5      174     253
# 6      172     252
# 7      173     251
# 8      171     253
# 9      171     258
# 10     169     259
# 11     158     267
# 12     156     274
# 13     150     274
# 14     150     276
# 15     147     279
# 16     143     280
# 17     139     282
# 18     140     284
# 19     140     288
# 20     138     290
# 21     136     291
# 22     134     291
# 23     132     292
# 24     130     294
# 25     131     294
# 26     131     297
# 27     131     299
# 28     129     301
# 29     125     300
# 30     123     298
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            212           212
# 1            211           211
# 2            212           212
# 3            211           211
# 4            210           210
# 5            210           210
# 6            212           212
# 7            211           211
# 8            198           198
# 9            195           230
# 10           188           231
# 11           186           235
# 12           185           237
# 13           180           237
# 14           180           238
# 15           179           241
# 16           183           244
# 17           179           244
# 18           180           247
# 19           177           243
# 20           177           244
# 21           178           244
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 430)
# Average_threshold: 4995.0
# Image 8cell_ABpl_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_ABpl_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      164     264
# 1      168     261
# 2      170     260
# 3      173     256
# 4      178     251
# 5      177     251
# 6      177     250
# 7      178     251
# 8      176     251
# 9      174     256
# 10     171     256
# 11     165     266
# 12     159     271
# 13     156     272
# 14     154     275
# 15     151     277
# 16     150     279
# 17     149     278
# 18     147     281
# 19     146     283
# 20     143     285
# 21     142     286
# 22     142     286
# 23     141     288
# 24     140     293
# 25     138     289
# 26     139     292
# 27     137     293
# 28     136     291
# 29     135     294
# 30     135     292
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            216           216
# 1            217           217
# 2            216           216
# 3            215           215
# 4            215           215
# 5            213           213
# 6            216           216
# 7            214           214
# 8            210           222
# 9            199           232
# 10           196           235
# 11           191           238
# 12           190           240
# 13           187           241
# 14           186           242
# 15           187           246
# 16           183           244
# 17           183           245
# 18           182           245
# 19           179           243
# 20           179           245
# 21           180           244
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 460)
# Average_threshold: 4995.0
# Image 8cell_ABpr_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_ABpr_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      186     277
# 1      189     274
# 2      190     272
# 3      195     269
# 4      193     268
# 5      195     268
# 6      194     270
# 7      194     270
# 8      191     272
# 9      190     272
# 10     187     276
# 11     183     279
# 12     180     284
# 13     176     288
# 14     174     291
# 15     171     292
# 16     167     294
# 17     165     300
# 18     164     298
# 19     163     302
# 20     160     302
# 21     162     307
# 22     160     303
# 23     158     305
# 24     158     302
# 25     156     305
# 26     159     305
# 27     155     306
# 28     155     306
# 29     156     307
# 30     158     307
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            229           229
# 1            228           228
# 2            228           228
# 3            228           228
# 4            228           228
# 5            229           229
# 6            227           227
# 7            229           229
# 8            224           235
# 9            218           242
# 10           215           247
# 11           210           251
# 12           209           255
# 13           205           256
# 14           205           259
# 15           201           256
# 16           203           260
# 17           200           258
# 18           201           262
# 19           200           261
# 20           201           260
# 21           205           258
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 430)
# Average_threshold: 4995.0
# Image 8cell_C_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_C_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      175     257
# 1      176     254
# 2      178     253
# 3      180     251
# 4      182     249
# 5      182     250
# 6      181     248
# 7      180     250
# 8      178     250
# 9      176     252
# 10     173     256
# 11     168     260
# 12     165     264
# 13     164     268
# 14     163     266
# 15     161     269
# 16     159     269
# 17     159     271
# 18     157     272
# 19     156     273
# 20     155     275
# 21     154     274
# 22     154     273
# 23     152     275
# 24     152     274
# 25     152     274
# 26     150     275
# 27     151     276
# 28     155     275
# 29     156     273
# 30     155     273
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            210           210
# 1            211           211
# 2            212           212
# 3            211           211
# 4            211           211
# 5            211           211
# 6            210           210
# 7            210           210
# 8            205           218
# 9            200           225
# 10           196           227
# 11           192           230
# 12           192           232
# 13           189           233
# 14           189           235
# 15           189           235
# 16           186           235
# 17           185           237
# 18           185           235
# 19           182           234
# 20           185           236
# 21           184           236
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 510)
# Average_threshold: 4995.0
# Image 8cell_E_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_E_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      219     292
# 1      223     288
# 2      224     289
# 3      223     290
# 4      223     292
# 5      218     289
# 6      223     289
# 7      225     292
# 8      220     292
# 9      219     294
# 10     213     296
# 11     209     301
# 12     202     304
# 13     306     306
# 14     309     309
# 15     312     312
# 16     314     314
# 17     311     311
# 18     316     316
# 19     316     316
# 20     315     315
# 21     319     319
# 22     319     319
# 23     320     320
# 24     318     318
# 25     319     319
# 26     316     316
# 27     318     318
# 28     321     321
# 29     320     320
# 30     321     321
# Error: maxima were incorrectly detected D:/data/Analysis Data/kymo_analysis/E32/8cell_E_kymo.tif
# (2, 31, 500)
# Average_threshold: 4995.0
# Image 8cell_MS_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_MS_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      211     290
# 1      211     290
# 2      217     285
# 3      220     281
# 4      219     286
# 5      219     284
# 6      216     283
# 7      218     283
# 8      216     284
# 9      213     286
# 10     211     291
# 11     206     294
# 12     200     300
# 13     199     301
# 14     197     303
# 15     195     304
# 16     192     307
# 17     189     308
# 18     190     308
# 19     191     309
# 20     188     312
# 21     188     310
# 22     186     314
# 23     186     313
# 24     188     315
# 25     186     314
# 26     184     315
# 27     185     312
# 28     186     315
# 29     183     315
# 30     182     316
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            252           252
# 1            250           250
# 2            252           252
# 3            251           251
# 4            250           250
# 5            249           249
# 6            249           249
# 7            249           249
# 8            254           254
# 9            239           261
# 10           233           265
# 11           228           268
# 12           229           271
# 13           224           270
# 14           222           271
# 15           224           272
# 16           226           276
# 17           222           276
# 18           221           276
# 19           223           281
# 20           216           275
# 21           226           266
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# (2, 31, 370)
# Average_threshold: 4995.0
# Image 8cell_P3_kymo.tif can be nicely processed with threshold: 4995.0
# 8cell_P3_kymo.tif : filtered
# Pole maxima positions
#      pole_1  pole_2
# 0      157     212
# 1      157     211
# 2      158     210
# 3      159     211
# 4      158     213
# 5      156     212
# 6      153     213
# 7      156     212
# 8      154     216
# 9      153     216
# 10     149     219
# 11     146     222
# 12     139     227
# 13     139     231
# 14     137     233
# 15     136     233
# 16     134     236
# 17     134     235
# 18     132     236
# 19     129     240
# 20     129     242
# 21     128     241
# 22     125     239
# 23     126     240
# 24     126     242
# 25     125     244
# 26     124     124
# 27     125     125
# 28     125     125
# 29     125     125
# 30     124     124
# Chromosome maxima positions
#      chromosome_1  chromosome_2
# 0            186           186
# 1            187           187
# 2            185           185
# 3            185           185
# 4            186           186
# 5            188           188
# 6            188           188
# 7            189           189
# 8            179           197
# 9            173           204
# 10           169           209
# 11           169           214
# 12           166           212
# 13           163           215
# 14           163           216
# 15           160           216
# 16           159           220
# 17           159           220
# 18           156           218
# 19           155           217
# 20           156           220
# 21           156           221
# Quality:  1.0
# Centromsome distance
# Chromosome distance
# High quality detection:  13
# Low quality detection:  0
# Number of errors:  1
