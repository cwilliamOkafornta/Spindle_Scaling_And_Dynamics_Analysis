# %% [markdown]
# # Value Extraction for making a Boxplot
# ### This script is used to the call the library `BoxPlotValuesExtraction.py` which is used to extract the column values from the csv file generated after running the curve fitting algorithm.
# ### `INPUT FILES`: csv files from the curve fitting calculation
# ### `OUTPUT FILES`: csv files that contain the computed length measurement values. Each column of the table represents the length measurement data or different cell stage.

# %%
import os
import pandas as pd
from BoxPlotValuesExtraction import PoleToPole_CSVvalues_BoxPlot, PoleToChromosome_CSVvalues_BoxPlot, ChromosomeToChromosome_CSVvalues_BoxPlot

# %%
# input folder
folder = r'D:\data\Analysis Data\python_analysis\input'

# output folder
save_files = r'D:\data\Analysis Data\python_analysis\output'

# %%
# call functions
'''Pole-to-pole data extraction'''
# PoleToPole_CSVvalues_BoxPlot(folder, save_files)

'''Pole-to-chromosome data extraction'''
PoleToChromosome_CSVvalues_BoxPlot(folder, save_files)

'''Chromosome-to-chromosome data extraction'''
# ChromosomeToChromosome_CSVvalues_BoxPlot(folder, save_files)
# Out:
# 'Chromosome-to-chromosome data extraction'
