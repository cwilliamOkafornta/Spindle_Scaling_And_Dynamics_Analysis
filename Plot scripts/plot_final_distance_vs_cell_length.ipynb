# %%
# library packages
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.stats import linregress
from plotFinalDistanceCellLength import PlotCellVolumeLength

# %%
# input folder
folder = r'D:\data\Analysis Data\python_analysis\input'
fileTable = os.listdir(folder)

# # output folder
save_files = r'D:\data\Analysis Data\python_analysis\output'

# %%
# call the plot function
PlotCellVolumeLength(folder, save_files, fileTable, 'distance_vs_cell_volume (wild type)', 'plot_slope_r_value (wild type)')
